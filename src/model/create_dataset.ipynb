# %%
import cv2
import os
import re
import numpy as np
import albumentations as A
import shutil
import os
import random
import shutil

# %%
directory = '../../data/starting_dataset/images'

for filename in os.listdir(directory):
    match = re.match(r'Лист \((\d+)\)\.jpg', filename)
    if match:
        number = match.group(1)
        new_filename = f'list_{number}.jpg'
        old_file = os.path.join(directory, filename)
        new_file = os.path.join(directory, new_filename)
        os.rename(old_file, new_file)
    else:
        print(f'Skipped: {filename}')

# %%
directory = '../../data/starting_dataset/defects'

for filename in os.listdir(directory):
    match = re.match(r'(\d+)_Лист \((\d+)\)_(.+)\.jpg', filename)
    if match:
        part1 = match.group(1)
        part2 = match.group(2)
        uuid = match.group(3)
        new_filename = f'{part1}_list_{part2}_{uuid}.jpg'
        old_file = os.path.join(directory, filename)
        new_file = os.path.join(directory, new_filename)
        os.rename(old_file, new_file)
    else:
        print(f'Skipped: {filename}')

# %%
def calculate_yolo_bbox(original_shape, cropped_shape, top_left):
    orig_height, orig_width = original_shape[:2]
    crop_height, crop_width = cropped_shape[:2]
    
    center_x = (top_left[0] + crop_width / 2) / orig_width
    center_y = (top_left[1] + crop_height / 2) / orig_height

    bbox_width = crop_width / orig_width
    bbox_height = crop_height / orig_height

    return center_x, center_y, bbox_width, bbox_height

# %%
original_images_dir = '../../data/starting_dataset/images'
cropped_images_dir = '../../data/starting_dataset/defects'
output_dir = '../../data/starting_dataset/labels'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
for filename in os.listdir(cropped_images_dir):
    match = re.match(r'(\d+)_list_(\d+)_(.+)\.jpg', filename)
    if match:
        cropped_image_path = os.path.join(cropped_images_dir, filename)

        number = match.group(1)
        list_number = match.group(2)
        uuid = match.group(3)
        
        original_image_filename = f'list_{list_number}.jpg'
        original_image_path = os.path.join(original_images_dir, original_image_filename)

        original_image = cv2.imread(original_image_path)
        cropped_image = cv2.imread(cropped_image_path)

        if original_image is None or cropped_image is None:
            print(f"Error: Couldn't load image(s) for {filename}")
            continue

        result = cv2.matchTemplate(original_image, cropped_image, cv2.TM_CCOEFF_NORMED)
        _, _, _, max_loc = cv2.minMaxLoc(result)

        yolo_bbox = calculate_yolo_bbox(original_image.shape, cropped_image.shape, max_loc)

        annotation_filename = f'list_{list_number}.txt'
        annotation_path = os.path.join(output_dir, annotation_filename)
    
        with open(annotation_path, 'a') as f:
            f.write(f"0 {yolo_bbox[0]} {yolo_bbox[1]} {yolo_bbox[2]} {yolo_bbox[3]}\n")

        print(f"Annotation created for {filename}")

    else:
        print(f"Skipped: {filename}")
# Out:
# Annotation created for 0_list_114_498bd161-204b-4594-b5b1-2e643de6770b.jpg
# Annotation created for 0_list_115_be5c0d43-f8de-4178-ac1d-9b6ad228975e.jpg
# Annotation created for 10_list_23_6f2337ce-9aba-44a7-8e97-514f96193162.jpg
# Annotation created for 11_list_23_890497ed-9439-4dd6-8490-cea696e8a0b7.jpg
# Annotation created for 11_list_96_8cb31424-b0b4-4689-809f-97e9dfd129fe.jpg
# Annotation created for 12_list_63_50437b1b-2eb6-43df-95c2-b2c13e21d4de.jpg
# Annotation created for 13_list_50_1815bfb2-8f30-411d-b7f5-cfc31d63540a.jpg
# Annotation created for 13_list_94_ecbef8b2-72cb-4d6c-9fd5-e60f7071e837.jpg
# Annotation created for 14_list_34_6f169b74-0f32-43cc-aff8-4dd3c453d3d2.jpg
# Annotation created for 15_list_34_fa118a77-021f-4f13-ba90-12d359a0b551.jpg
# Annotation created for 15_list_45_3a6813d9-876a-4a19-8509-df593b46df2d.jpg
# Error: Couldn't load image(s) for 15_list_70_b106323e-6026-452e-a4bb-2ce0283a92c7.jpg
# Error: Couldn't load image(s) for 15_list_87_e6c246cc-b496-4f0b-aab4-c9de15e7fd00.jpg
# Annotation created for 16_list_14_a589f223-e4e4-4a2d-91a2-59541d37445d.jpg
# Annotation created for 17_list_14_95c0fc43-4d7c-4d6d-8593-74a6b9361640.jpg
# Annotation created for 18_list_111_a2148a7f-d384-4078-9b4b-46d7792cc692.jpg
# Annotation created for 18_list_119_f2125b06-3134-462b-aac9-b9ba8bd15970.jpg
# Annotation created for 18_list_31_1636de57-1b69-4578-b2a4-4930bde69cae.jpg
# Annotation created for 18_list_44_6a514186-98a6-421f-892e-cacc0bb4ee0a.jpg
# Annotation created for 19_list_119_015ec6f8-7473-4462-b1c4-4af2082dff80.jpg
# Annotation created for 19_list_94_bd6b56f5-07e8-4175-8880-3a394117727f.jpg
# Annotation created for 19_list_96_b7690b77-087c-41ff-8932-5f04bc8e7bac.jpg
# Annotation created for 20_list_119_911e5502-7ba2-43e1-8e48-7f87c8d0d8ec.jpg
# Annotation created for 20_list_50_051d4037-bfd5-446d-87b1-5f253f649114.jpg
# Annotation created for 20_list_54_964a000e-312d-4a45-affa-123f525fe399.jpg
# Annotation created for 20_list_94_5fa63e6e-c3e2-46cd-82d6-fc8f134bfb1b.jpg
# Annotation created for 21_list_119_ea66d1dd-7f1d-465f-b30e-c9f8b22f2f6d.jpg
# Annotation created for 21_list_45_3100ce4d-464d-402c-a814-ed39af50b035.jpg
# Annotation created for 21_list_48_de79b4dd-8a49-4ed6-8a61-2ffbbff10544.jpg
# Annotation created for 21_list_94_36ef77f3-7519-45fd-9f6a-ef25c7182c6f.jpg
# Annotation created for 22_list_48_e6d7d874-8c14-425b-aab7-24cdcd21824f.jpg
# Annotation created for 22_list_54_61d5fa80-9c80-43cc-8f37-cd28c3745dfe.jpg
# Annotation created for 22_list_96_8d8a2e83-42e9-4f9e-9a48-b0df5eca5d48.jpg
# Annotation created for 23_list_119_fa2cfff5-d4b2-48ac-905e-308fb9980498.jpg
# Annotation created for 23_list_41_7b20e59d-1706-4c04-9faa-eb3dd25bf5ac.jpg
# Annotation created for 23_list_63_6d6003c1-b5d6-451f-8b31-a125bdbadc49.jpg
# Annotation created for 24_list_119_90dfdc4e-123d-4ca7-8ba3-ec48f8ecdd74.jpg
# Annotation created for 24_list_54_4d0f5ac1-815e-4c76-a8fc-f2e0b11c9588.jpg
# Annotation created for 24_list_63_e9379bbe-8c76-4613-880d-e152f11490f6.jpg
# Annotation created for 25_list_119_fd2bea79-1c15-4a6f-b85c-ee27e7b29164.jpg
# Annotation created for 25_list_44_ecb71f14-3f02-45ad-8c88-7b910f88887e.jpg
# Annotation created for 25_list_50_2411ad98-da56-41cd-ad6c-44d91a6e40c9.jpg
# Annotation created for 26_list_54_bf728308-ebc7-4f5f-a23a-3877159142cd.jpg
# Annotation created for 26_list_63_d923c39a-ffb6-46d1-8c37-9ef87569eb5c.jpg
# Annotation created for 28_list_105_d3d5df15-5da3-4918-9cc0-72aabcfefbc9.jpg
# Annotation created for 28_list_41_1cf23b21-a5a1-4a65-bf87-4ff2125870e9.jpg
# Annotation created for 32_list_20_b3eb39d9-ca79-420c-bc73-0b7dcd742f3b.jpg
# Annotation created for 33_list_105_f150dc04-417b-4e16-b770-50e91bf9bdb4.jpg
# Annotation created for 33_list_23_32e16592-47a9-4506-9c0b-3a790cd26d04.jpg
# Annotation created for 34_list_45_151cd5a1-23bb-418e-b133-9be0c3d2e82e.jpg
# Annotation created for 36_list_102_009b639b-7762-4107-84c3-a6ba02921119.jpg
# Error: Couldn't load image(s) for 36_list_10_e20646cc-a3a9-42b1-86a1-8e8a3a9490ac.jpg
# Error: Couldn't load image(s) for 36_list_116_fb25c21c-a4fd-4ff3-81e4-10849f700613.jpg
# Annotation created for 36_list_42_0d394cff-2049-4ab2-986a-6dbe47f9d3d7.jpg
# Annotation created for 39_list_45_c43a2d72-2982-4583-bafd-9b2eaa8db56e.jpg
# Annotation created for 39_list_4_1dcdabdc-1cf8-4de9-a170-69e6d851da8b.jpg
# Annotation created for 39_list_54_131d64c9-8bb8-41cd-8839-4ceb842aaf01.jpg
# Annotation created for 40_list_42_976c0fc6-7691-47cb-b2c9-c1715babcf69.jpg
# Annotation created for 41_list_102_3fa95ce3-3329-44ef-b898-4c37d2d5056f.jpg
# Annotation created for 42_list_42_cacf0442-44a8-4907-b5f0-ff0a0da3273b.jpg
# Annotation created for 43_list_54_3b352202-d7f4-439f-9a33-286c5a7aae1e.jpg
# Annotation created for 44_list_50_53ec0019-54e6-46ef-85b6-d05b0cc75f8d.jpg
# Annotation created for 48_list_34_ebf13138-ae06-4135-8593-77ae8778d54b.jpg
# Error: Couldn't load image(s) for 4_list_10_2f6569bc-c1a4-4791-b500-84a57bbe2189.jpg
# Error: Couldn't load image(s) for 4_list_116_0a33ee56-c63c-484a-9c3a-e976fb96bd7b.jpg
# Annotation created for 4_list_45_a5e87cfa-df4f-4527-976e-77164fcd9263.jpg
# Annotation created for 50_list_20_82857790-d8e0-48dd-9e6d-d45f5072e737.jpg
# Annotation created for 51_list_19_5bb17ae0-11be-4b1f-a783-695c08a5a777.jpg
# Annotation created for 51_list_54_edf742a1-f3bb-483f-9f2f-ae40ad076371.jpg
# Annotation created for 51_list_90_82bb609a-324a-47de-93c2-244d1b1b0dcf.jpg
# Error: Couldn't load image(s) for 5_list_10_d310d962-c19d-45b4-8d0a-8d3c6a88007e.jpg
# Error: Couldn't load image(s) for 5_list_116_02747689-98c5-4365-969c-fb9f5826c476.jpg
# Annotation created for 5_list_9_ec8ffd14-43d4-4e77-bfa5-6fd7271d1602.jpg
# Annotation created for 60_list_4_1c93a425-32c1-4743-8538-1eb7e81d9a14.jpg
# Annotation created for 62_list_119_01d4965d-4f73-485e-9c43-68706049357d.jpg
# Error: Couldn't load image(s) for 63_list_18_46aa9910-8143-46fa-b27c-9f1ae37ff183.jpg
# Error: Couldn't load image(s) for 66_list_18_08d57277-ed1d-4092-b49e-cc294ca051d8.jpg
# Annotation created for 66_list_20_20f7b400-88a2-4197-8cb5-d0e46a8ecb8f.jpg
# Error: Couldn't load image(s) for 67_list_18_084c3313-97de-40ed-b502-0244d75a8486.jpg
# Error: Couldn't load image(s) for 69_list_18_0e286571-0fb0-491d-894b-49b17311ff9d.jpg
# Error: Couldn't load image(s) for 6_list_10_953f0c2e-215e-4697-9d66-1d941f432105.jpg
# Error: Couldn't load image(s) for 6_list_116_db8e3835-25b1-40a2-b0f8-550e49938232.jpg
# Annotation created for 6_list_63_4738791b-b925-4373-908c-36d9e7f3ad42.jpg
# Error: Couldn't load image(s) for 70_list_18_9179c282-5f00-4991-8ce8-5d728757d082.jpg
# Error: Couldn't load image(s) for 71_list_18_59185840-1f66-431c-a01b-f33a3b382dbb.jpg
# Error: Couldn't load image(s) for 72_list_110_dfd2c4de-dbd2-4344-ab41-251d71a266a5.jpg
# Error: Couldn't load image(s) for 72_list_18_70cafb3e-ce38-41c0-92fe-9cd0d0b6d29d.jpg
# Error: Couldn't load image(s) for 73_list_18_d5927064-3965-4030-96df-156bda5caa81.jpg
# Annotation created for 73_list_4_a3dd7208-f4cc-4989-8886-7f2f2fe06a0b.jpg
# Error: Couldn't load image(s) for 75_list_110_fdc39c82-5c9f-4306-9007-b31574ef4bb6.jpg
# Error: Couldn't load image(s) for 76_list_110_b1b670e2-613a-4146-b608-368934ee9944.jpg
# Annotation created for 77_list_99_188c7a5d-3bbb-4d47-9bc3-5edc622a5ec1.jpg
# Error: Couldn't load image(s) for 78_list_110_396c3f03-fec3-4609-b99b-2e0f26017239.jpg
# Error: Couldn't load image(s) for 79_list_110_9e2ebd1b-f819-4dcc-88cb-df8e784b42f4.jpg
# Error: Couldn't load image(s) for 7_list_10_3844af41-ca4d-4731-a854-fbc2d62b0cce.jpg
# Error: Couldn't load image(s) for 7_list_116_76aeb5b8-e943-4182-ae61-2fa062939a9e.jpg
# Annotation created for 7_list_63_4378d2ef-0e66-416f-8493-72494f55137e.jpg
# Annotation created for 7_list_99_5be1bc0c-3255-487b-ae61-754820afccd9.jpg
# Error: Couldn't load image(s) for 80_list_110_454f64ec-beea-4464-a441-919c8dad30c7.jpg
# Error: Couldn't load image(s) for 81_list_110_bc0dd9b4-77ac-4929-8620-73fc5c66440a.jpg
# Error: Couldn't load image(s) for 82_list_110_1d594d3e-8072-4722-91f2-ea0265091e72.jpg
# Error: Couldn't load image(s) for 8_list_10_1b62c87e-67ec-45f9-8c78-5c69041334eb.jpg
# Error: Couldn't load image(s) for 8_list_116_14fe468d-76b8-43b8-8e2f-63d29b85cbcb.jpg
# Annotation created for 8_list_23_abe0c94b-adfe-452a-b89f-2412b6507b8d.jpg

# %% [markdown]
# отсуствуют картинки 110, 10, 116, 18, 70, 87

# %%
images_dir = '../../data/starting_dataset/images'
labels_dir = '../../data/starting_dataset/labels'
for filename in os.listdir(images_dir):
    filename = filename.replace('.jpg', '.txt')
    file_path = os.path.join(labels_dir, filename)
    if not os.path.exists(file_path):
        with open(file_path, 'w') as f:
            pass

# %%
aug = A.Compose([
    A.RandomBrightnessContrast(p=0.2),
    A.HueSaturationValue(p=0.2),
    A.GaussianBlur(p=0.1),
])

def read_label_file(file_path):
    with open(file_path, 'r') as f:
        labels = f.readlines()
    return labels

def write_label_file(file_path, labels):
    with open(file_path, 'w') as f:
        f.writelines(labels)

def augment_images_and_labels(image_dir, label_dir, output_image_dir, output_label_dir, num_augmentations=10):
    image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

    for image_file in image_files:
        base_name = os.path.splitext(image_file)[0]
        image_path = os.path.join(image_dir, image_file)
        label_path = os.path.join(label_dir, base_name + '.txt')

        shutil.copy(image_path, os.path.join(output_image_dir, image_file))
        shutil.copy(label_path, os.path.join(output_label_dir, base_name + '.txt'))

        image = cv2.imread(image_path)
        labels = read_label_file(label_path)

        for i in range(num_augmentations):
            augmented = aug(image=image)
            augmented_image = augmented['image']

            if isinstance(augmented_image, np.ndarray):
                aug_image_file = f"{base_name}_aug_{i}.jpg"
                aug_image_path = os.path.join(output_image_dir, aug_image_file)
                cv2.imwrite(aug_image_path, augmented_image)

                aug_label_file = f"{base_name}_aug_{i}.txt"
                aug_label_path = os.path.join(output_label_dir, aug_label_file)
                write_label_file(aug_label_path, labels)
            else:
                print(f"Augmentation failed for {image_file}")

image_dir = '../../data/starting_dataset/images'
label_dir = '../../data/starting_dataset/labels'
output_image_dir = '../../data/aug_dataset/images'
output_label_dir = '../../data/aug_dataset/labels'

os.makedirs(output_image_dir, exist_ok=True)
os.makedirs(output_label_dir, exist_ok=True)

augment_images_and_labels(image_dir, label_dir, output_image_dir, output_label_dir)

# %%
def split_dataset(image_dir, label_dir, train_image_dir, train_label_dir, val_image_dir, val_label_dir, val_split=0.2):
    image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
    random.shuffle(image_files)

    num_val = int(len(image_files) * val_split)
    val_files = image_files[:num_val]
    train_files = image_files[num_val:]

    for image_file in train_files:
        base_name = os.path.splitext(image_file)[0]
        label_file = base_name + '.txt'

        shutil.copy(os.path.join(image_dir, image_file), os.path.join(train_image_dir, image_file))
        shutil.copy(os.path.join(label_dir, label_file), os.path.join(train_label_dir, label_file))

    for image_file in val_files:
        base_name = os.path.splitext(image_file)[0]
        label_file = base_name + '.txt'

        shutil.copy(os.path.join(image_dir, image_file), os.path.join(val_image_dir, image_file))
        shutil.copy(os.path.join(label_dir, label_file), os.path.join(val_label_dir, label_file))

image_dir = '../../data/aug_dataset/images'
label_dir = '../../data/aug_dataset/labels'
train_image_dir = '../../data/aug_dataset/train/images'
train_label_dir = '../../data/aug_dataset/train/labels'
val_image_dir = '../../data/aug_dataset/val/images'
val_label_dir = '../../data/aug_dataset/val/labels'

os.makedirs(train_image_dir, exist_ok=True)
os.makedirs(train_label_dir, exist_ok=True)
os.makedirs(val_image_dir, exist_ok=True)
os.makedirs(val_label_dir, exist_ok=True)

split_dataset(image_dir, label_dir, train_image_dir, train_label_dir, val_image_dir, val_label_dir)

# %%
def draw_boxes(image_path, label_path, class_names):
    image = cv2.imread(image_path)
    height, width, _ = image.shape
    
    with open(label_path, 'r') as file:
        labels = file.readlines()
        
    for label in labels:
        parts = label.strip().split()
        class_id = int(parts[0])
        center_x = float(parts[1]) * width
        center_y = float(parts[2]) * height
        box_width = float(parts[3]) * width
        box_height = float(parts[4]) * height

        x1 = int(center_x - box_width / 2)
        y1 = int(center_y - box_height / 2)
        x2 = int(center_x + box_width / 2)
        y2 = int(center_y + box_height / 2)
        
        color = (255, 0, 0)
        thickness = 2 
        cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)
        
        label_text = class_names[class_id]
        cv2.putText(image, label_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
    
    return image

image_dir = '../../data/starting_dataset/images'
label_dir = '../../data/starting_dataset/labels'
output_dir = 'output'
class_names = ['defect']

os.makedirs(output_dir, exist_ok=True)

image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

for image_file in image_files:
    base_name = os.path.splitext(image_file)[0]
    image_path = os.path.join(image_dir, image_file)
    label_path = os.path.join(label_dir, base_name + '.txt')

    if os.path.exists(label_path):
        image_with_boxes = draw_boxes(image_path, label_path, class_names)
        
        output_path = os.path.join(output_dir, image_file)
        cv2.imwrite(output_path, image_with_boxes)
    else:
        print(f"Label file not found for {image_file}")

print("Bounding boxes visualization completed.")
# Out:
# Bounding boxes visualization completed.
